# %% [markdown]
# ## **Simulation and Modeling Lab**
#
# Name: Abdur Rahman Jayed
#
# Student ID: 0432320005101106
#
# Course Code: CSE 413
#
# Section : **7B**

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1: Scalar & Array Operations
#
# We will use a scalar value `3.7` and a custom NumPy array with 6 elements,
# then apply various built-in mathematical functions to both.

# %%
# Sample scalar and array inputs
scalar = 3.7
arr = np.array([1.7, 3.9, 6.2, 8.4, 10.1, 12.6])

# Trigonometric functions
sin_values = np.sin(arr)
cos_values = np.cos(arr)
tan_values = np.tan(arr)
asin_values = np.arcsin(np.clip(arr / np.max(arr), -1, 1))  # Normalized and Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(arr / np.max(arr), -1, 1))
atan_values = np.arctan(arr)

# Exponential and logarithm
exp_values = np.exp(arr)
log_values = np.log(arr)  # Natural logarithm

# Absolute value and square root
abs_values = np.abs(arr)
sqrt_values = np.sqrt(arr)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(arr, 2)

# Rounding functions
round_values = np.round(arr)
floor_values = np.floor(arr)
ceil_values = np.ceil(arr)

# Display results
print("sin:", sin_values)
print("cos:", cos_values)
print("tan:", tan_values)
print("asin:", asin_values)
print("acos:", acos_values)
print("atan:", atan_values)
print("exp:", exp_values)
print("log:", log_values)
print("abs:", abs_values)
print("sqrt:", sqrt_values)
print("rem:", rem_values)
print("round:", round_values)
print("floor:", floor_values)
print("ceil:", ceil_values)
# Out:
# sin: [ 0.99166481 -0.68776616 -0.0830894   0.85459891 -0.62507065  0.03362305]
# cos: [-0.12884449 -0.7259323   0.9965421  -0.51928865 -0.78056818  0.99943459]
# tan: [-7.69660214  0.94742465 -0.08337771 -1.64571073  0.8007893   0.03364207]
# asin: [0.13533336 0.31469221 0.51445848 0.72972766 0.92994541 1.57079633]
# acos: [1.43546296 1.25610412 1.05633785 0.84106867 0.64085092 0.        ]
# atan: [1.03907226 1.31979364 1.4108832  1.45230637 1.47210807 1.49159726]
# exp: [5.47394739e+00 4.94024491e+01 4.92749041e+02 4.44706675e+03
#  2.43430094e+04 2.96558565e+05]
# log: [0.53062825 1.36097655 1.82454929 2.12823171 2.31253542 2.53369681]
# abs: [ 1.7  3.9  6.2  8.4 10.1 12.6]
# sqrt: [1.30384048 1.97484177 2.48997992 2.89827535 3.17804972 3.54964787]
# rem: [1.7 1.9 0.2 0.4 0.1 0.6]
# round: [ 2.  4.  6.  8. 10. 13.]
# floor: [ 1.  3.  6.  8. 10. 12.]
# ceil: [ 2.  4.  7.  9. 11. 13.]

# %% [markdown]
# ## Task 2: 3×2 Matrix Calculations

# %%
# Creating a 3x2 matrix
matrix = np.array([[2.4, 5.7], [3.8, 6.9], [7.5, 9.2]])

# Trigonometric functions
sin_values = np.sin(matrix)
cos_values = np.cos(matrix)
tan_values = np.tan(matrix)
asin_values = np.arcsin(np.clip(matrix / np.max(matrix), -1, 1))  # Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(matrix / np.max(matrix), -1, 1))
atan_values = np.arctan(matrix)

# Exponential and logarithm
exp_values = np.exp(matrix)
log_values = np.log(matrix)  # Natural logarithm (log base e)

# Absolute value and square root
abs_values = np.abs(matrix)
sqrt_values = np.sqrt(matrix)

# Remainder when divided by 2
rem_values = np.remainder(matrix, 2)

# Rounding functions
round_values = np.round(matrix)
floor_values = np.floor(matrix)
ceil_values = np.ceil(matrix)

# Display results
print("Matrix:\n", matrix)
print("\nsin:\n", sin_values)
print("\ncos:\n", cos_values)
print("\ntan:\n", tan_values)
print("\nasin:\n", asin_values)
print("\nacos:\n", acos_values)
print("\natan:\n", atan_values)
print("\nexp:\n", exp_values)
print("\nlog:\n", log_values)
print("\nabs:\n", abs_values)
print("\nsqrt:\n", sqrt_values)
print("\nrem (remainder when divided by 2):\n", rem_values)
print("\nround:\n", round_values)
print("\nfloor:\n", floor_values)
print("\nceil:\n", ceil_values)
# Out:
# Matrix:
#  [[2.4 5.7]
#  [3.8 6.9]
#  [7.5 9.2]]
#
# sin:
#  [[ 0.67546318 -0.55068554]
#  [-0.61185789  0.57843976]
#  [ 0.93799998  0.22288991]]
#
# cos:
#  [[-0.73739372  0.83471278]
#  [-0.79096771  0.8157251 ]
#  [ 0.34663532 -0.97484362]]
#
# tan:
#  [[-0.91601429 -0.65973057]
#  [ 0.77355609  0.70911115]
#  [ 2.70601387 -0.22864171]]
#
# asin:
#  [[0.26392285 0.66818868]
#  [0.42579341 0.84806208]
#  [0.95310446 1.57079633]]
#
# acos:
#  [[1.30687348 0.90260765]
#  [1.14500292 0.72273425]
#  [0.61769187 0.        ]]
#
# atan:
#  [[1.17600521 1.39712513]
#  [1.31347261 1.42687088]
#  [1.43824479 1.46252574]]
#
# exp:
#  [[  11.02317638  298.86740097]
#  [  44.70118449  992.27471561]
#  [1808.04241446 9897.12905874]]
#
# log:
#  [[0.87546874 1.74046617]
#  [1.33500107 1.93152141]
#  [2.01490302 2.21920348]]
#
# abs:
#  [[2.4 5.7]
#  [3.8 6.9]
#  [7.5 9.2]]
#
# sqrt:
#  [[1.54919334 2.38746728]
#  [1.94935887 2.62678511]
#  [2.73861279 3.03315018]]
#
# rem (remainder when divided by 2):
#  [[0.4 1.7]
#  [1.8 0.9]
#  [1.5 1.2]]
#
# round:
#  [[2. 6.]
#  [4. 7.]
#  [8. 9.]]
#
# floor:
#  [[2. 5.]
#  [3. 6.]
#  [7. 9.]]
#
# ceil:
#  [[ 3.  6.]
#  [ 4.  7.]
#  [ 8. 10.]]

# %% [markdown]
# ## Task 3: Vector Functions on a 2×3 Matrix

# %%
# Sample 2×3 matrix (float values)
mat = np.array([
    [3.6, 7.2, 2.8],
    [9.4, 5.1, 6.7]
])

# 1. Maximum value and index of max element
max_value = np.max(mat)
max_index = np.argmax(mat)

# 2. Minimum value and index of min element
min_value = np.min(mat)
min_index = np.argmin(mat)

# 3. Total number of elements in the matrix
mat_length = mat.size

# 4. Row-wise sorting in descending order
row_sorted = np.sort(mat, axis=1)[:, ::-1]

# 5. Entire matrix sorting in descending order
entire_sorted = np.sort(mat.flatten())[::-1]

# 6. Sum of all elements
sum_values = np.sum(mat)

# 7. Product of all elements
prod_values = np.prod(mat)

# 8. Median value
median_value = np.median(mat)

# 9. Mean value
mean_value = np.mean(mat)

# 10. Standard deviation
std_dev = np.std(mat)

# Display results
print("Matrix:")
print(mat)

print("\nMax value:", max_value, "at index", max_index)
print("Min value:", min_value, "at index", min_index)
print("Total number of elements:", mat_length)

print("\nRow-wise descending sort:")
print(row_sorted)

print("\nEntire matrix descending sort:")
print(entire_sorted)

print("\nSum of elements:", sum_values)
print("Product of elements:", prod_values)
print("Median value:", median_value)
print("Mean value:", mean_value)
print("Standard deviation:", std_dev)
# Out:
# Matrix:
# [[3.6 7.2 2.8]
#  [9.4 5.1 6.7]]
#
# Max value: 9.4 at index 3
# Min value: 2.8 at index 2
# Total number of elements: 6
#
# Row-wise descending sort:
# [[7.2 3.6 2.8]
#  [9.4 6.7 5.1]]
#
# Entire matrix descending sort:
# [9.4 7.2 6.7 5.1 3.6 2.8]
#
# Sum of elements: 34.800000000000004
# Product of elements: 23311.266047999998
# Median value: 5.9
# Mean value: 5.800000000000001
# Standard deviation: 2.238302928559939

# %% [markdown]
# ## **🧠 Bonus**

# %%
# Sample 2×3 matrix
mat = np.array([
    [3.6, 7.2, 2.8],
    [9.4, 5.1, 6.7]
])

# Heatmap visualization
plt.figure(figsize=(5, 3))
sns.heatmap(mat, annot=True, cmap="YlGnBu", fmt=".1f")
plt.title("Heatmap of 2×3 Matrix")
plt.show()
